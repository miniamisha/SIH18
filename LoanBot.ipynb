# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
color = sns.color_palette()
import squarify

# %%
# Importing the dataset
funding_data = pd.read_csv('/home/amisha/startup_funding.csv')

# %%
# missing data 
total = funding_data.isnull().sum().sort_values(ascending = False)
percent = ((funding_data.isnull().sum()/funding_data.isnull().count())*100).sort_values(ascending = False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent %'])
missing_data.head()
# Out:
#                   Total  Percent %
# Yearly Salary        51  34.228188
# Source of grants      0   0.000000
# InvestmentType        0   0.000000
# Scheme Opted          0   0.000000
# CityLocation          0   0.000000

# %%
industry = funding_data['IndustryVertical'].value_counts().head(10)
print(industry)
plt.figure(figsize=(15,8))
sns.barplot(industry.index, industry.values, alpha=0.9, color=color[0])
plt.xticks(rotation='vertical')
plt.xlabel('Industry vertical of startups', fontsize=12)
plt.ylabel('Number of fundings made', fontsize=12)
plt.title("Industry vertical of startups with number of funding", fontsize=16)
plt.show()
# Out:
# Consumer Internet    70
# Technology           45
# eCommerce            19
# Agriculture           9
# Healthcare            2
# Logistics             2
# Others                1
# Food & Beverage       1
# Name: IndustryVertical, dtype: int64

# %%
city = funding_data['CityLocation'].value_counts().head(10)
print(city)
plt.figure(figsize=(15,8))
sns.barplot(city.index, city.values, alpha=0.9, color=color[0])
plt.xticks(rotation='vertical')
plt.xlabel('city location of startups', fontsize=12)
plt.ylabel('Number of fundings made', fontsize=12)
plt.title("city location of startups with number of funding", fontsize=16)
plt.show()
# Out:
# Bangalore     52
# Mumbai        30
# New Delhi     21
# Hyderabad     14
# Gurgaon       12
# Pune           8
# Noida          6
# Ahmedabad      2
# Kolkata        2
# Trivandrum     1
# Name: CityLocation, dtype: int64

# %%
plt.figure(figsize=(15,8))
count = funding_data['CityLocation'].value_counts()
squarify.plot(sizes=count.values,label=count.index, value=count.values)
plt.title('Distribution of Startups across Top cities')

# %%
investors = funding_data['Scheme Opted'].value_counts().head(10)
print('Scheme Opted')
plt.figure(figsize=(15,8))
sns.barplot(investors.index, investors.values, alpha=0.9, color=color[0])
plt.xticks(rotation='vertical')
plt.xlabel('Scheme Opted', fontsize=12)
plt.ylabel('Number of fundings made', fontsize=12)
plt.title("Scheme Opted Names with number of funding", fontsize=16)
plt.show()
# Out:
# Scheme Opted

# %%
investment = funding_data['Collateral'].value_counts()
print('Collateral')
plt.figure(figsize=(15,8))
sns.barplot(count.index, count.values, alpha=0.9, color=color[1])
plt.xticks(rotation='vertical')
plt.xlabel('Collateral', fontsize=12)
plt.ylabel('Number of fundings made', fontsize=12)
plt.title("Collateral with number of funding", fontsize=16)
plt.show()
# Out:
# Collateral

# %%
X = funding_data.iloc[:, 3].values
y = funding_data.iloc[:, 6].values

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)
# Out:
# /home/amisha/.local/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# categorical data
from sklearn.preprocessing import LabelEncoder , OneHotEncoder
#labelencoder_X = LabelEncoder()
#X[:3] = labelencoder_X.fit_transform(X[:3]).shape
onehotencoder=OneHotEncoder(categorical_features=[0])
X = onehotencoder.fit_transform(X).toarray()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-8078c2dd457b> in <module>()
#       4 #X[:3] = labelencoder_X.fit_transform(X[:3]).shape
#       5 onehotencoder=OneHotEncoder(categorical_features=[0])
# ----> 6 X = onehotencoder.fit_transform(X).toarray()
#
# /home/amisha/.local/lib/python2.7/site-packages/sklearn/preprocessing/data.pyc in fit_transform(self, X, y)
#    2017         """
#    2018         return _transform_selected(X, self._fit_transform,
# -> 2019                                    self.categorical_features, copy=True)
#    2020
#    2021     def _transform(self, X):
#
# /home/amisha/.local/lib/python2.7/site-packages/sklearn/preprocessing/data.pyc in _transform_selected(X, transform, selected, copy)
#    1807     X : array or sparse matrix, shape=(n_samples, n_features_new)
#    1808     """
# -> 1809     X = check_array(X, accept_sparse='csc', copy=copy, dtype=FLOAT_DTYPES)
#    1810
#    1811     if isinstance(selected, six.string_types) and selected == "all":
#
# /home/amisha/.local/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: Online Travel Marketplace
