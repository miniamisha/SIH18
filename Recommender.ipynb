# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
color = sns.color_palette()
import squarify

# %%
funding_data = pd.read_csv('/home/amisha/startup_funding.csv')

# %%
funding_data
# Out:
#      SNo Collateral          StartupName   IndustryVertical  \
# 0      0        yes             TouchKin         Technology
# 1      1         no              Ethinos         Technology
# 2      2         no         Leverage Edu  Consumer Internet
# 3      3        yes                 Zepo  Consumer Internet
# 4      4         no         Click2Clinic        Agriculture
# 5      5         no        Billion Loans  Consumer Internet
# 6      6         no     Ecolibriumenergy         Technology
# 7      7         no                Droom          eCommerce
# 8      8        yes            Jumbotail          eCommerce
# 9      9        yes               Moglix          eCommerce
# 10    10         no           Timesaverz  Consumer Internet
# 11    11         no               Minjar         Technology
# 12    12        yes          MyCity4kids  Consumer Internet
# 13    13        yes             Clip App  Consumer Internet
# 14    14        yes          Upwardly.in  Consumer Internet
# 15    15         no           Autorox.co         Technology
# 16    16         no               Fabogo        Agriculture
# 17    17        yes           Flickstree  Consumer Internet
# 18    18         no          Design Cafe  Consumer Internet
# 19    19        yes             Innoviti         Technology
# 20    20        yes             VDeliver          Logistics
# 21    21         no             Bottr.me         Technology
# 22    22         no             Arcatron         Technology
# 23    23         no             QwikSpec         Technology
# 24    24        yes              Chumbak          eCommerce
# 25    25        yes              Increff         Technology
# 26    26         no               Vayana         Technology
# 27    27         no            MObiquest        Agriculture
# 28    28        yes                Ambee  Consumer Internet
# 29    29        yes      Ideal Insurance  Consumer Internet
# ..   ...        ...                  ...                ...
# 119  119        yes                  Ola  Consumer Internet
# 120  120         no               Sumeru         Technology
# 121  121         no           Healthians  Consumer Internet
# 122  122         no            HealthMir  Consumer Internet
# 123  123         no              Uactive  Consumer Internet
# 124  124        yes               i-lend  Consumer Internet
# 125  125         no  Good Methods Global         Technology
# 126  126        yes          Balance App  Consumer Internet
# 127  127         no                YepMe          eCommerce
# 128  128        yes            Nightstay  Consumer Internet
# 129  129         no             Devourin         Technology
# 130  130        yes             MyGreens    Food & Beverage
# 131  131         no           Ace Turtle         Technology
# 132  132        yes              CureFit         Technology
# 133  133         no           Curie Labs         Technology
# 134  134        yes       Uncanny Vision         Technology
# 135  135        yes             Anchanto         Technology
# 136  136        yes            Sequretek         Technology
# 137  137        yes             Lucideus         Technology
# 138  138        yes              Vidooly  Consumer Internet
# 139  139        yes            Shopclues          eCommerce
# 140  140         no         Fourth Ambit  Consumer Internet
# 141  141         no           Chymera VR         Technology
# 142  142         no         Early Salary  Consumer Internet
# 143  143         no      Book My Diamond          eCommerce
# 144  144         no           ION Energy         Technology
# 145  145         no         Legal Raasta  Consumer Internet
# 146  146         no      Log 9 Materials         Technology
# 147  147         no           Remit Guru  Consumer Internet
# 148  148        yes                Aequm          eCommerce
#
#                                            SubVertical CityLocation  \
# 0                             Predictive Care Platform    Bangalore
# 1                             Digital Marketing Agency       Mumbai
# 2        Online platform for Higher Education Services    New Delhi
# 3                               DIY Ecommerce platform       Mumbai
# 4            Dairy Entrepreneurship Development Scheme    Hyderabad
# 5                        Peer to Peer Lending platform    Bangalore
# 6                 Energy management solutions provider    Ahmedabad
# 7                   Online marketplace for automobiles      Gurgaon
# 8              online marketplace for food and grocery    Bangalore
# 9              B2B marketplace for Industrial products        Noida
# 10                   Hyperlocal home services provider       Mumbai
# 11                            Cloud Solutions provider    Bangalore
# 12   parenting blog and kids‚Äô events discover...      Gurgaon
# 13                        Digital Media Video platform    Bangalore
# 14                              MF investment platform    Bangalore
# 15               Workshop Management Software Platform    Hyderabad
# 16    Small Farmers’ Agri-Business Consortium (SFAC)         Pune
# 17                    Video Content Discovery Platform       Mumbai
# 18                     Online Interior Design platform    Bangalore
# 19                          Digital payments solutions    Bangalore
# 20                         Door Step Delivery platform    Hyderabad
# 21                               Chatbot creation tool    Bangalore
# 22               Next Gen Mobility device manufacturer         Pune
# 23   Construction site operations and analytics pla...    Bangalore
# 24              Designer consumer products Marketplace    Bangalore
# 25                  Sales Solutions for Fashion Brands    Bangalore
# 26                        Enterprise Banking Solutions         Pune
# 27                                  Coir Udyami Yojana         Pune
# 28                      Ambulance Aggregation Services    Hyderabad
# 29                           Online Insurance platform      Kolkata
# ..                                                 ...          ...
# 119                                Cab Aggregation App    Bangalore
# 120             Software & Mobile development services    Bangalore
# 121           Online Diagnostics and wellness platform    New Delhi
# 122                   AI-based health content platform    New Delhi
# 123     Health-based social networking & discovery App       Mumbai
# 124                      Peer-to-peer lending platform    Hyderabad
# 125           Cloud Based Practice Management Software   Trivandrum
# 126                     Money Savings & Management App    Bangalore
# 127                      Private Label Fashion etailer      Gurgaon
# 128               Last minute hotel booking mobile app    New Delhi
# 129                     Restaurant Automation Solution         Pune
# 130                     Cold-press Juices manufacturer    New Delhi
# 131                              Omni-Channel Platform    Bangalore
# 132                               Health-Tech Platform    Bangalore
# 133                           Energy Analytics startup    New Delhi
# 134                Computer Vision on Embedded Systems    Bangalore
# 135       Ecommerce Fulfilment and Technology Platform         Pune
# 136             IT Security & Data Management Services       Mumbai
# 137                             Cyber Security Startup    New Delhi
# 138                        Video Intelligence platform        Noida
# 139                                 Online marketplace      Gurgaon
# 140                        Community Building platform    Bangalore
# 141           Advertising Platform for Virtual Reality    Bangalore
# 142                            Online lending platform         Pune
# 143                                Diamond B2B eTailer       Mumbai
# 144                                 Clean Tech Startup       Mumbai
# 145               Legal Services to SMEs & Individuals    New Delhi
# 146                         NanoTech product developer    Bangalore
# 147                    Digital money transfer platform       Mumbai
# 148                           Cloud ECommerce platform    Bangalore
#
#                                           Scheme Opted  InvestmentType  \
# 0    \nSupport for International Patent Protection ...  Private Equity
# 1        Software Technology Park (STP) Scheme          Private Equity
# 2    \nSupport for International Patent Protection ...    Seed Funding
# 3                                                SIDBI    Seed Funding
# 4    The incentives differ with respect to the cost...    Seed Funding
# 5                Software Technology Park (STP) Scheme    Seed Funding
# 6                  Atal Tinkering Laboratories          Private Equity
# 7                Software Technology Park (STP) Scheme  Private Equity
# 8        Software Technology Park (STP) Scheme          Private Equity
# 9        Software Technology Park (STP) Scheme          Private Equity
# 10   Support for International Patent Protection in...  Private Equity
# 11   Blume Ventures, Contrarian Capital India Partn...    Seed Funding
# 12   Support for International Patent Protection in...    Seed Funding
# 13   Support for International Patent Protection in...    Seed Funding
# 14   Support for International Patent Protection in...    Seed Funding
# 15               Software Technology Park (STP) Scheme  Private Equity
# 16   The quantum of SFAC Venture Capital Assistance...  Private Equity
# 17   Support for International Patent Protection in...    Seed Funding
# 18                      Multiplier Grants Scheme (MGS)    Seed Funding
# 19                                        SBI-FMO Fund  Private Equity
# 20   \nElectronic Development Fund (EDF) Policy    ...  Private Equity
# 21                       Software Technology Park(STP)    Seed Funding
# 22            Electronic Development Fund (EDF) Policy    Seed Funding
# 23                 \nInfrastructure Development Scheme    Seed Funding
# 24                       Software Technology Park(STP)  Private Equity
# 25   Support for International Patent Protection in...    Seed Funding
# 26                       Software Technology Park(STP)  Private Equity
# 27   The amount of bank credit will be 55% of the t...  Private Equity
# 28                       Atal Incubation Centres (AIC)    Seed Funding
# 29                       Atal Incubation Centres (AIC)    Seed Funding
# ..                                                 ...             ...
# 119          Falcon Edge Capital,¬Ý Capital Advisers  Private Equity
# 120                                         EDF Policy    Seed Funding
# 121  Asuka Holdings, YouWeCan Ventures, Beenext, Be...  Private Equity
# 122                                    Nimit Panigrahi    Seed Funding
# 123                                     Hinduja family    Seed Funding
# 124                                       50K Ventures    Seed Funding
# 125                                         EDF Policy  Private Equity
# 126                                         Rainmatter    Seed Funding
# 127  Rainbow Digital Services Pvt. Ltd, ILearnFinan...  Private Equity
# 128                 Indian Angels Network, LetsVenture    Seed Funding
# 129                                         EDF Policy    Seed Funding
# 130                            Ajay Relan, LetsVenture    Seed Funding
# 131      Software Technology Park (STP) Scheme          Private Equity
# 132  RNT Capital, Gokul Rajaram, Aditya Agarwal, Ru...  Private Equity
# 133                                    Satoshi Studios    Seed Funding
# 134                               Anand Chandrasekaran    Seed Funding
# 135                                      Luxasia Group  Private Equity
# 136                       GVFL, Unicorn India Ventures  Private Equity
# 137  Vellayan Subbiah, Jonathan Boutelle, Rajan Ana...    Seed Funding
# 138                               Times Internet, GVFL  Private Equity
# 139                                    InnoVen Capital  Private Equity
# 140                                             1Crowd    Seed Funding
# 141  Varsha Rao, Surojit Chatterjee, Nirav Choksi &...    Seed Funding
# 142      DG Ventures India, Dewan Housing Finance Corp  Private Equity
# 143                       Chirag Nikunj Sheth & Others    Seed Funding
# 144     Aakrit Vaish, Swapan Rajdev, Sushill Jiwarajka    Seed Funding
# 145                                    Impanix Capital  Private Equity
# 146                                               GEMs    Seed Funding
# 147                                 Infibeam, CCavenue  Private Equity
# 148                              undisclosed investors    Seed Funding
#
#      Yearly Salary Source of grants
# 0         130000.0          central
# 1              NaN            state
# 2              NaN            state
# 3          50000.0          central
# 4         850000.0            state
# 5         100000.0          central
# 6         260000.0            state
# 7         200000.0          central
# 8        8500000.0            state
# 9         120000.0          central
# 10        100000.0          central
# 11        343000.0          central
# 12             NaN          central
# 13        100000.0          central
# 14             NaN          central
# 15        300000.0            state
# 16        225000.0            state
# 17        464000.0          central
# 18       3400000.0          central
# 19        180000.0          central
# 20             NaN          central
# 21             NaN          central
# 22             NaN          central
# 23        540000.0            state
# 24         17000.0            state
# 25        200000.0            state
# 26        400000.0            state
# 27             NaN            state
# 28             NaN          central
# 29             NaN            state
# ..             ...              ...
# 119    104500000.0          central
# 120      1000000.0          central
# 121            NaN            state
# 122            NaN            state
# 123            NaN            state
# 124            NaN            state
# 125            NaN          central
# 126       233000.0          central
# 127       700000.0            state
# 128            NaN          central
# 129            NaN            state
# 130      1000000.0          central
# 131      5000000.0          central
# 132      3000000.0          central
# 133        50000.0            state
# 134            NaN            state
# 135            NaN            state
# 136            NaN            state
# 137            NaN            state
# 138      1400000.0            state
# 139      7700000.0          central
# 140       600000.0            state
# 141            NaN          central
# 142      4000000.0            state
# 143            NaN          central
# 144            NaN            state
# 145      5000000.0          central
# 146            NaN          central
# 147       466000.0          central
# 148      1000000.0          central
#
# [149 rows x 10 columns]

# %%
X = funding_data.iloc[:, 4].values
y = funding_data.iloc[:, 6].values

# %%
# categorical data
#from sklearn.preprocessing import  OneHotEncoder
#labelencoder_X= LabelEncoder()
#X[:, 3] = labelencoder_X.fit_transform(X[:, 3])
#onehotencoder=OneHotEncoder(categorical_features=[0])
#X[:, 3] = onehotencoder.fit_transform(X).toarray()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-f629114aaad2> in <module>()
#       4 #X[:, 3] = labelencoder_X.fit_transform(X[:, 3])
#       5 onehotencoder=OneHotEncoder(categorical_features=[0])
# ----> 6 X[:, 3] = onehotencoder.fit_transform(X).toarray()
#
# /home/amisha/.local/lib/python2.7/site-packages/sklearn/preprocessing/data.pyc in fit_transform(self, X, y)
#    2017         """
#    2018         return _transform_selected(X, self._fit_transform,
# -> 2019                                    self.categorical_features, copy=True)
#    2020
#    2021     def _transform(self, X):
#
# /home/amisha/.local/lib/python2.7/site-packages/sklearn/preprocessing/data.pyc in _transform_selected(X, transform, selected, copy)
#    1807     X : array or sparse matrix, shape=(n_samples, n_features_new)
#    1808     """
# -> 1809     X = check_array(X, accept_sparse='csc', copy=copy, dtype=FLOAT_DTYPES)
#    1810
#    1811     if isinstance(selected, six.string_types) and selected == "all":
#
# /home/amisha/.local/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: eCommerce

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)
# Out:
# /home/amisha/.local/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#from sklearn.preprocessing import LabelEncoder
#labelencoder_X=LabelEncoder()
#X[:, 4]=labelencoder_X.fit_transform(X[:, 4])

cleanup_nums = {"IndustryVertical":     {"Consumer Internet": 0, "Technology": 1,"eCommerce": 2,"Agriculture": 3,"Logistics": 4,"Others": 5,"Food & Beverage": 6}}

# %%
funding_data.replace(cleanup_nums, inplace=True)
funding_data.tail()
# Out:
#      SNo Collateral      StartupName IndustryVertical  \
# 144  144         no       ION Energy                1
# 145  145         no     Legal Raasta                0
# 146  146         no  Log 9 Materials                1
# 147  147         no       Remit Guru                0
# 148  148        yes            Aequm                2
#
#                               SubVertical CityLocation  \
# 144                    Clean Tech Startup       Mumbai
# 145  Legal Services to SMEs & Individuals    New Delhi
# 146            NanoTech product developer    Bangalore
# 147       Digital money transfer platform       Mumbai
# 148              Cloud ECommerce platform    Bangalore
#
#                                        Scheme Opted  InvestmentType  \
# 144  Aakrit Vaish, Swapan Rajdev, Sushill Jiwarajka    Seed Funding
# 145                                 Impanix Capital  Private Equity
# 146                                            GEMs    Seed Funding
# 147                              Infibeam, CCavenue  Private Equity
# 148                           undisclosed investors    Seed Funding
#
#      Yearly Salary Source of grants
# 144            NaN            state
# 145      5000000.0          central
# 146            NaN          central
# 147       466000.0          central
# 148      1000000.0          central
